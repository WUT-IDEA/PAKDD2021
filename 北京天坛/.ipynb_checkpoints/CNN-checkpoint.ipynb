# %%
from keras.models import Model
from keras.layers import Input, Dense, LSTM, multiply, concatenate, Activation, Masking, Reshape,RepeatVector
from keras.layers import Conv1D, BatchNormalization, GlobalAveragePooling1D, Permute, Dropout,MaxPooling1D,AveragePooling1D,Flatten,Bidirectional


import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils.data_split import split_sequence_parallel

# 不加这几句，则CONV 报错
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
data = pd.read_csv("D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\\InfoGainTiantandata.csv", header=0,infer_datetime_format=True, engine='python')
data['Unnamed: 0']=pd.to_datetime(data['Unnamed: 0'])
data.set_index("Unnamed: 0",inplace=True)

# %%
'''
归一化
'''
from sklearn.preprocessing import MinMaxScaler
scaler1 = MinMaxScaler(feature_range=(0, 1))
scaler2 = MinMaxScaler(feature_range=(0, 1))
scaler3 = MinMaxScaler(feature_range=(0, 1))
scaler4 = MinMaxScaler(feature_range=(0, 1))
scaler5 = MinMaxScaler(feature_range=(0, 1))
scaler6 = MinMaxScaler(feature_range=(0, 1))
scaler7 = MinMaxScaler(feature_range=(0, 1))
scaler8 = MinMaxScaler(feature_range=(0, 1))
scaler9 = MinMaxScaler(feature_range=(0, 1))
scaler10 = MinMaxScaler(feature_range=(0, 1))
scaler11 = MinMaxScaler(feature_range=(0, 1))
scaler12 = MinMaxScaler(feature_range=(0, 1))
scaler13 = MinMaxScaler(feature_range=(0, 1))
scaler14 = MinMaxScaler(feature_range=(0, 1))
scaler15 = MinMaxScaler(feature_range=(0, 1))
data_minmax = data.copy()
data_minmax['PM2.5']=scaler1.fit_transform(data_minmax['PM2.5'].values.reshape(-1,1))
data_minmax['PM10']=scaler2.fit_transform(data_minmax['PM10'].values.reshape(-1,1))
data_minmax['SO2']=scaler3.fit_transform(data_minmax['SO2'].values.reshape(-1,1))
data_minmax['NO2']=scaler4.fit_transform(data_minmax['NO2'].values.reshape(-1,1))
data_minmax['CO']=scaler5.fit_transform(data_minmax['CO'].values.reshape(-1,1))
data_minmax['O3']=scaler6.fit_transform(data_minmax['O3'].values.reshape(-1,1))
data_minmax['TEMP']=scaler7.fit_transform(data_minmax['TEMP'].values.reshape(-1,1))
data_minmax['PRES']=scaler8.fit_transform(data_minmax['PRES'].values.reshape(-1,1))
data_minmax['DEWP']=scaler9.fit_transform(data_minmax['DEWP'].values.reshape(-1,1))
data_minmax['wd_E']=scaler10.fit_transform(data_minmax['wd_E'].values.reshape(-1,1))
data_minmax['wd_ENE']=scaler11.fit_transform(data_minmax['wd_ENE'].values.reshape(-1,1))
data_minmax['wd_ESE']=scaler12.fit_transform(data_minmax['wd_ESE'].values.reshape(-1,1))
data_minmax['wd_NE']=scaler13.fit_transform(data_minmax['wd_NE'].values.reshape(-1,1))
data_minmax['wd_NW']=scaler14.fit_transform(data_minmax['wd_NW'].values.reshape(-1,1))
data_minmax['wd_SW']=scaler15.fit_transform(data_minmax['wd_SW'].values.reshape(-1,1))

# %%
'''
取一年的时间，10个月做训练和验证，2个月做测试
'''
cast1 = -10200
cast2 = -2880
cast3 = -1416                                                                      
data_train = data_minmax[cast1:cast2]
data_test = data_minmax[cast2:cast3] 
data_train.shape,data_test.shape
# Out:
# ((7320, 15), (1464, 15))

# %%
data_test = np.array(data_test)
data_train = np.array(data_train)
data_train.shape,data_test.shape
# Out:
# ((7320, 15), (1464, 15))

# %%
sw_width = 21
pred_length = 7
verbose_set = 2
X, y, features = split_sequence_parallel(data_train,sw_width,pred_length)
test_x,test_y,test_features = split_sequence_parallel(data_test,sw_width,pred_length)

# %%
def CNN():
    ip = Input(shape=(sw_width,features))

    y = Conv1D(128, 5, padding='same', kernel_initializer='he_uniform')(ip) 
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = MaxPooling1D(pool_size=2)(y)
    y = Flatten()(y)
    
    y = Dense(100)(y)
    y = Dropout(0.5)(y)
    out = Dense(pred_length)(y)

    model = Model(ip, out)
    model.summary()
    return model

# %%
CNN_model1 = CNN()
CNN_model1
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 21, 15)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 21, 128)           9728
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 128)           512
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 128)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 10, 128)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               128100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 707
# =================================================================
# Total params: 139,047
# Trainable params: 138,791
# Non-trainable params: 256
# _________________________________________________________________

# %%
import time
from keras import backend as K
from keras.callbacks import ModelCheckpoint
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true))) 

filepath = "D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min', period=1)
callbacks_list = [checkpoint]
starttime=time.time()
CNN_model1.compile(loss=root_mean_squared_error, optimizer='adam')
history1 = CNN_model1.fit(X,y,validation_split=0.33,epochs=100, batch_size=32,callbacks=callbacks_list, verbose=2)
endtime=time.time()
dtime=endtime-starttime
print("程序运行时间为：%.8s s" % dtime)  #时间显示到微秒
# Out:
# Train on 4886 samples, validate on 2407 samples
# Epoch 1/100
#  - 14s - loss: 0.8281 - val_loss: 0.1353
#
# Epoch 00001: val_loss improved from inf to 0.13531, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 2/100
#  - 1s - loss: 0.3448 - val_loss: 0.1317
#
# Epoch 00002: val_loss improved from 0.13531 to 0.13175, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 3/100
#  - 1s - loss: 0.1639 - val_loss: 0.0651
#
# Epoch 00003: val_loss improved from 0.13175 to 0.06510, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 4/100
#  - 1s - loss: 0.0794 - val_loss: 0.0500
#
# Epoch 00004: val_loss improved from 0.06510 to 0.04999, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 5/100
#  - 1s - loss: 0.0545 - val_loss: 0.0370
#
# Epoch 00005: val_loss improved from 0.04999 to 0.03697, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 6/100
#  - 1s - loss: 0.0511 - val_loss: 0.0381
#
# Epoch 00006: val_loss did not improve from 0.03697
# Epoch 7/100
#  - 1s - loss: 0.0490 - val_loss: 0.0457
#
# Epoch 00007: val_loss did not improve from 0.03697
# Epoch 8/100
#  - 1s - loss: 0.0492 - val_loss: 0.0371
#
# Epoch 00008: val_loss did not improve from 0.03697
# Epoch 9/100
#  - 1s - loss: 0.0495 - val_loss: 0.0376
#
# Epoch 00009: val_loss did not improve from 0.03697
# Epoch 10/100
#  - 1s - loss: 0.0478 - val_loss: 0.0366
#
# Epoch 00010: val_loss improved from 0.03697 to 0.03658, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\weights\CNN_model_weights_best.hdf5
# Epoch 11/100
#  - 1s - loss: 0.0470 - val_loss: 0.0385
#
# Epoch 00011: val_loss did not improve from 0.03658
# Epoch 12/100
#  - 1s - loss: 0.0458 - val_loss: 0.0405
#
# Epoch 00012: val_loss did not improve from 0.03658
# Epoch 13/100
#  - 1s - loss: 0.0474 - val_loss: 0.0371
#
# Epoch 00013: val_loss did not improve from 0.03658
# Epoch 14/100
#  - 1s - loss: 0.0459 - val_loss: 0.0368
#
# Epoch 00014: val_loss did not improve from 0.03658
# Epoch 15/100
#  - 1s - loss: 0.0454 - val_loss: 0.0391
#
# Epoch 00015: val_loss did not improve from 0.03658
# Epoch 16/100
#  - 1s - loss: 0.0446 - val_loss: 0.0418
#
# Epoch 00016: val_loss did not improve from 0.03658
# Epoch 17/100
#  - 1s - loss: 0.0452 - val_loss: 0.0388
#
# Epoch 00017: val_loss did not improve from 0.03658
# Epoch 18/100
#  - 1s - loss: 0.0450 - val_loss: 0.0380
#
# Epoch 00018: val_loss did not improve from 0.03658
# Epoch 19/100
#  - 1s - loss: 0.0435 - val_loss: 0.0387
#
# Epoch 00019: val_loss did not improve from 0.03658
# Epoch 20/100
#  - 1s - loss: 0.0436 - val_loss: 0.0387
#
# Epoch 00020: val_loss did not improve from 0.03658
# Epoch 21/100
#  - 1s - loss: 0.0441 - val_loss: 0.0412
#
# Epoch 00021: val_loss did not improve from 0.03658
# Epoch 22/100
#  - 1s - loss: 0.0441 - val_loss: 0.0382
#
# Epoch 00022: val_loss did not improve from 0.03658
# Epoch 23/100
#  - 1s - loss: 0.0431 - val_loss: 0.0485
#
# Epoch 00023: val_loss did not improve from 0.03658
# Epoch 24/100
#  - 1s - loss: 0.0429 - val_loss: 0.0398
#
# Epoch 00024: val_loss did not improve from 0.03658
# Epoch 25/100
#  - 1s - loss: 0.0429 - val_loss: 0.0444
#
# Epoch 00025: val_loss did not improve from 0.03658
# Epoch 26/100
#  - 1s - loss: 0.0416 - val_loss: 0.0429
#
# Epoch 00026: val_loss did not improve from 0.03658
# Epoch 27/100
#  - 1s - loss: 0.0408 - val_loss: 0.0395
#
# Epoch 00027: val_loss did not improve from 0.03658
# Epoch 28/100
#  - 1s - loss: 0.0417 - val_loss: 0.0402
#
# Epoch 00028: val_loss did not improve from 0.03658
# Epoch 29/100
#  - 1s - loss: 0.0402 - val_loss: 0.0441
#
# Epoch 00029: val_loss did not improve from 0.03658
# Epoch 30/100
#  - 1s - loss: 0.0409 - val_loss: 0.0476
#
# Epoch 00030: val_loss did not improve from 0.03658
# Epoch 31/100
#  - 1s - loss: 0.0396 - val_loss: 0.0397
#
# Epoch 00031: val_loss did not improve from 0.03658
# Epoch 32/100
#  - 1s - loss: 0.0391 - val_loss: 0.0455
#
# Epoch 00032: val_loss did not improve from 0.03658
# Epoch 33/100
#  - 1s - loss: 0.0394 - val_loss: 0.0443
#
# Epoch 00033: val_loss did not improve from 0.03658
# Epoch 34/100
#  - 1s - loss: 0.0389 - val_loss: 0.0420
#
# Epoch 00034: val_loss did not improve from 0.03658
# Epoch 35/100
#  - 1s - loss: 0.0388 - val_loss: 0.0470
#
# Epoch 00035: val_loss did not improve from 0.03658
# Epoch 36/100
#  - 1s - loss: 0.0382 - val_loss: 0.0428
#
# Epoch 00036: val_loss did not improve from 0.03658
# Epoch 37/100
#  - 1s - loss: 0.0384 - val_loss: 0.0429
#
# Epoch 00037: val_loss did not improve from 0.03658
# Epoch 38/100
#  - 1s - loss: 0.0366 - val_loss: 0.0510
#
# Epoch 00038: val_loss did not improve from 0.03658
# Epoch 39/100
#  - 1s - loss: 0.0372 - val_loss: 0.0434
#
# Epoch 00039: val_loss did not improve from 0.03658
# Epoch 40/100
#  - 1s - loss: 0.0366 - val_loss: 0.0403
#
# Epoch 00040: val_loss did not improve from 0.03658
# Epoch 41/100
#  - 1s - loss: 0.0351 - val_loss: 0.0444
#
# Epoch 00041: val_loss did not improve from 0.03658
# Epoch 42/100
#  - 1s - loss: 0.0357 - val_loss: 0.0461
#
# Epoch 00042: val_loss did not improve from 0.03658
# Epoch 43/100
#  - 1s - loss: 0.0359 - val_loss: 0.0419
#
# Epoch 00043: val_loss did not improve from 0.03658
# Epoch 44/100
#  - 1s - loss: 0.0351 - val_loss: 0.0413
#
# Epoch 00044: val_loss did not improve from 0.03658
# Epoch 45/100
#  - 1s - loss: 0.0340 - val_loss: 0.0487
#
# Epoch 00045: val_loss did not improve from 0.03658
# Epoch 46/100
#  - 1s - loss: 0.0353 - val_loss: 0.0432
#
# Epoch 00046: val_loss did not improve from 0.03658
# Epoch 47/100
#  - 1s - loss: 0.0340 - val_loss: 0.0429
#
# Epoch 00047: val_loss did not improve from 0.03658
# Epoch 48/100
#  - 1s - loss: 0.0326 - val_loss: 0.0422
#
# Epoch 00048: val_loss did not improve from 0.03658
# Epoch 49/100
#  - 1s - loss: 0.0334 - val_loss: 0.0447
#
# Epoch 00049: val_loss did not improve from 0.03658
# Epoch 50/100
#  - 1s - loss: 0.0324 - val_loss: 0.0428
#
# Epoch 00050: val_loss did not improve from 0.03658
# Epoch 51/100
#  - 1s - loss: 0.0335 - val_loss: 0.0407
#
# Epoch 00051: val_loss did not improve from 0.03658
# Epoch 52/100
#  - 1s - loss: 0.0335 - val_loss: 0.0441
#
# Epoch 00052: val_loss did not improve from 0.03658
# Epoch 53/100
#  - 1s - loss: 0.0329 - val_loss: 0.0495
#
# Epoch 00053: val_loss did not improve from 0.03658
# Epoch 54/100
#  - 1s - loss: 0.0317 - val_loss: 0.0412
#
# Epoch 00054: val_loss did not improve from 0.03658
# Epoch 55/100
#  - 1s - loss: 0.0321 - val_loss: 0.0459
#
# Epoch 00055: val_loss did not improve from 0.03658
# Epoch 56/100
#  - 1s - loss: 0.0317 - val_loss: 0.0433
#
# Epoch 00056: val_loss did not improve from 0.03658
# Epoch 57/100
#  - 1s - loss: 0.0315 - val_loss: 0.0482
#
# Epoch 00057: val_loss did not improve from 0.03658
# Epoch 58/100
#  - 1s - loss: 0.0306 - val_loss: 0.0485
#
# Epoch 00058: val_loss did not improve from 0.03658
# Epoch 59/100
#  - 1s - loss: 0.0306 - val_loss: 0.0473
#
# Epoch 00059: val_loss did not improve from 0.03658
# Epoch 60/100
#  - 1s - loss: 0.0307 - val_loss: 0.0481
#
# Epoch 00060: val_loss did not improve from 0.03658
# Epoch 61/100
#  - 1s - loss: 0.0302 - val_loss: 0.0447
#
# Epoch 00061: val_loss did not improve from 0.03658
# Epoch 62/100
#  - 1s - loss: 0.0300 - val_loss: 0.0445
#
# Epoch 00062: val_loss did not improve from 0.03658
# Epoch 63/100
#  - 1s - loss: 0.0296 - val_loss: 0.0463
#
# Epoch 00063: val_loss did not improve from 0.03658
# Epoch 64/100
#  - 1s - loss: 0.0297 - val_loss: 0.0445
#
# Epoch 00064: val_loss did not improve from 0.03658
# Epoch 65/100
#  - 1s - loss: 0.0299 - val_loss: 0.0463
#
# Epoch 00065: val_loss did not improve from 0.03658
# Epoch 66/100
#  - 1s - loss: 0.0297 - val_loss: 0.0424
#
# Epoch 00066: val_loss did not improve from 0.03658
# Epoch 67/100
#  - 1s - loss: 0.0290 - val_loss: 0.0471
#
# Epoch 00067: val_loss did not improve from 0.03658
# Epoch 68/100
#  - 1s - loss: 0.0283 - val_loss: 0.0463
#
# Epoch 00068: val_loss did not improve from 0.03658
# Epoch 69/100
#  - 1s - loss: 0.0286 - val_loss: 0.0497
#
# Epoch 00069: val_loss did not improve from 0.03658
# Epoch 70/100
#  - 1s - loss: 0.0287 - val_loss: 0.0437
#
# Epoch 00070: val_loss did not improve from 0.03658
# Epoch 71/100
#  - 1s - loss: 0.0291 - val_loss: 0.0435
#
# Epoch 00071: val_loss did not improve from 0.03658
# Epoch 72/100
#  - 1s - loss: 0.0284 - val_loss: 0.0491
#
# Epoch 00072: val_loss did not improve from 0.03658
# Epoch 73/100
#  - 1s - loss: 0.0286 - val_loss: 0.0452
#
# Epoch 00073: val_loss did not improve from 0.03658
# Epoch 74/100
#  - 1s - loss: 0.0274 - val_loss: 0.0462
#
# Epoch 00074: val_loss did not improve from 0.03658
# Epoch 75/100
#  - 1s - loss: 0.0267 - val_loss: 0.0458
#
# Epoch 00075: val_loss did not improve from 0.03658
# Epoch 76/100
#  - 1s - loss: 0.0278 - val_loss: 0.0496
#
# Epoch 00076: val_loss did not improve from 0.03658
# Epoch 77/100
#  - 1s - loss: 0.0280 - val_loss: 0.0482
#
# Epoch 00077: val_loss did not improve from 0.03658
# Epoch 78/100
#  - 1s - loss: 0.0278 - val_loss: 0.0517
#
# Epoch 00078: val_loss did not improve from 0.03658
# Epoch 79/100
#  - 1s - loss: 0.0260 - val_loss: 0.0436
#
# Epoch 00079: val_loss did not improve from 0.03658
# Epoch 80/100
#  - 1s - loss: 0.0277 - val_loss: 0.0489
#
# Epoch 00080: val_loss did not improve from 0.03658
# Epoch 81/100
#  - 1s - loss: 0.0272 - val_loss: 0.0436
#
# Epoch 00081: val_loss did not improve from 0.03658
# Epoch 82/100
#  - 1s - loss: 0.0267 - val_loss: 0.0485
#
# Epoch 00082: val_loss did not improve from 0.03658
# Epoch 83/100
#  - 1s - loss: 0.0269 - val_loss: 0.0459
#
# Epoch 00083: val_loss did not improve from 0.03658
# Epoch 84/100
#  - 1s - loss: 0.0267 - val_loss: 0.0451
#
# Epoch 00084: val_loss did not improve from 0.03658
# Epoch 85/100
#  - 1s - loss: 0.0257 - val_loss: 0.0458
#
# Epoch 00085: val_loss did not improve from 0.03658
# Epoch 86/100
#  - 1s - loss: 0.0263 - val_loss: 0.0504
#
# Epoch 00086: val_loss did not improve from 0.03658
# Epoch 87/100
#  - 1s - loss: 0.0256 - val_loss: 0.0516
#
# Epoch 00087: val_loss did not improve from 0.03658
# Epoch 88/100
#  - 1s - loss: 0.0260 - val_loss: 0.0468
#
# Epoch 00088: val_loss did not improve from 0.03658
# Epoch 89/100
#  - 1s - loss: 0.0263 - val_loss: 0.0448
#
# Epoch 00089: val_loss did not improve from 0.03658
# Epoch 90/100
#  - 1s - loss: 0.0262 - val_loss: 0.0436
#
# Epoch 00090: val_loss did not improve from 0.03658
# Epoch 91/100
#  - 1s - loss: 0.0254 - val_loss: 0.0447
#
# Epoch 00091: val_loss did not improve from 0.03658
# Epoch 92/100
#  - 1s - loss: 0.0253 - val_loss: 0.0489
#
# Epoch 00092: val_loss did not improve from 0.03658
# Epoch 93/100
#  - 1s - loss: 0.0261 - val_loss: 0.0500
#
# Epoch 00093: val_loss did not improve from 0.03658
# Epoch 94/100
#  - 1s - loss: 0.0259 - val_loss: 0.0507
#
# Epoch 00094: val_loss did not improve from 0.03658
# Epoch 95/100
#  - 1s - loss: 0.0257 - val_loss: 0.0467
#
# Epoch 00095: val_loss did not improve from 0.03658
# Epoch 96/100
#  - 1s - loss: 0.0252 - val_loss: 0.0484
#
# Epoch 00096: val_loss did not improve from 0.03658
# Epoch 97/100
#  - 1s - loss: 0.0246 - val_loss: 0.0452
#
# Epoch 00097: val_loss did not improve from 0.03658
# Epoch 98/100
#  - 1s - loss: 0.0258 - val_loss: 0.0425
#
# Epoch 00098: val_loss did not improve from 0.03658
# Epoch 99/100
#  - 1s - loss: 0.0254 - val_loss: 0.0432
#
# Epoch 00099: val_loss did not improve from 0.03658
# Epoch 100/100
#  - 1s - loss: 0.0253 - val_loss: 0.0483
#
# Epoch 00100: val_loss did not improve from 0.03658
# 程序运行时间为：80.95839 s

# %%
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = np.arange(100) + 1
plt.figure(figsize=(20,18))
plt.plot(epochs, loss, label='loss')
plt.plot(epochs, val_loss, label='val_loss')
plt.title("Effect of model capacity on validation loss\n")
plt.xlabel('Epoch #')
plt.ylabel('Validation Loss')
plt.legend()
plt.show()

# %%
CNN_model1.load_weights(filepath)

# %%
predict=CNN_model1.predict(test_x)
predict=scaler1.inverse_transform(predict)

# %%
predict.shape,test_y.shape
# Out:
# ((1437, 7), (1437, 7))

# %%
tf.sqrt(tf.losses.mean_squared_error(predict,scaler1.inverse_transform(test_y))).numpy().mean()
# Out:
# 45.340706863342405
