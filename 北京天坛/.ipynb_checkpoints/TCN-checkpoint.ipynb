# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense
from tensorflow.keras import Input, Model
from utils.data_split import split_sequence_parallel
from utils.tcn import TCN, tcn_full_summary



# 不加这几句，则CONV 报错
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
data = pd.read_csv("D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\\InfoGainTiantandata.csv", header=0,infer_datetime_format=True, engine='python')
data['Unnamed: 0']=pd.to_datetime(data['Unnamed: 0'])
data.set_index("Unnamed: 0",inplace=True)

# %%
'''
归一化
'''
from sklearn.preprocessing import MinMaxScaler
scaler1 = MinMaxScaler(feature_range=(0, 1))
scaler2 = MinMaxScaler(feature_range=(0, 1))
scaler3 = MinMaxScaler(feature_range=(0, 1))
scaler4 = MinMaxScaler(feature_range=(0, 1))
scaler5 = MinMaxScaler(feature_range=(0, 1))
scaler6 = MinMaxScaler(feature_range=(0, 1))
scaler7 = MinMaxScaler(feature_range=(0, 1))
scaler8 = MinMaxScaler(feature_range=(0, 1))
scaler9 = MinMaxScaler(feature_range=(0, 1))
scaler10 = MinMaxScaler(feature_range=(0, 1))
scaler11 = MinMaxScaler(feature_range=(0, 1))
scaler12 = MinMaxScaler(feature_range=(0, 1))
scaler13 = MinMaxScaler(feature_range=(0, 1))
scaler14 = MinMaxScaler(feature_range=(0, 1))
scaler15 = MinMaxScaler(feature_range=(0, 1))
data_minmax = data.copy()
data_minmax['PM2.5']=scaler1.fit_transform(data_minmax['PM2.5'].values.reshape(-1,1))
data_minmax['PM10']=scaler2.fit_transform(data_minmax['PM10'].values.reshape(-1,1))
data_minmax['SO2']=scaler3.fit_transform(data_minmax['SO2'].values.reshape(-1,1))
data_minmax['NO2']=scaler4.fit_transform(data_minmax['NO2'].values.reshape(-1,1))
data_minmax['CO']=scaler5.fit_transform(data_minmax['CO'].values.reshape(-1,1))
data_minmax['O3']=scaler6.fit_transform(data_minmax['O3'].values.reshape(-1,1))
data_minmax['TEMP']=scaler7.fit_transform(data_minmax['TEMP'].values.reshape(-1,1))
data_minmax['PRES']=scaler8.fit_transform(data_minmax['PRES'].values.reshape(-1,1))
data_minmax['DEWP']=scaler9.fit_transform(data_minmax['DEWP'].values.reshape(-1,1))
data_minmax['wd_E']=scaler10.fit_transform(data_minmax['wd_E'].values.reshape(-1,1))
data_minmax['wd_ENE']=scaler11.fit_transform(data_minmax['wd_ENE'].values.reshape(-1,1))
data_minmax['wd_ESE']=scaler12.fit_transform(data_minmax['wd_ESE'].values.reshape(-1,1))
data_minmax['wd_NE']=scaler13.fit_transform(data_minmax['wd_NE'].values.reshape(-1,1))
data_minmax['wd_NW']=scaler14.fit_transform(data_minmax['wd_NW'].values.reshape(-1,1))
data_minmax['wd_SW']=scaler15.fit_transform(data_minmax['wd_SW'].values.reshape(-1,1))

# %%
'''
取一年的时间，10个月做训练和验证，2个月做测试
'''
cast1 = -10200
cast2 = -2880
cast3 = -1416                                                                      
data_train = data_minmax[cast1:cast2]
data_test = data_minmax[cast2:cast3] 
data_train.shape,data_test.shape
# Out:
# ((7320, 15), (1464, 15))

# %%
data_test = np.array(data_test)
data_train = np.array(data_train)
data_train.shape,data_test.shape
# Out:
# ((7320, 15), (1464, 15))

# %%
sw_width = 21
pred_length = 12
verbose_set = 2
X, y, features = split_sequence_parallel(data_train,sw_width,pred_length)
test_x,test_y,test_features = split_sequence_parallel(data_test,sw_width,pred_length)

# %%
def TCN_model():
    
    ip = Input(shape=(sw_width,features))

    x = TCN(return_sequences=False,nb_filters=200,kernel_size=2)(ip)

    
    out = Dense(pred_length)(x)
    model = Model(ip, out)
    model.summary()


    return model

# %%
TCN_model1 = TCN_model()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 21, 15)]          0
# _________________________________________________________________
# tcn_5 (TCN)                  (None, 200)               891600
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                2412
# =================================================================
# Total params: 894,012
# Trainable params: 894,012
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
from keras import backend as K
from keras.callbacks import ModelCheckpoint
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true))) 

filepath = "D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\\12hourweights\TCN_model_weights_best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min', period=1)
callbacks_list = [checkpoint]
starttime=time.time()
TCN_model1.compile(loss=root_mean_squared_error, optimizer='adam')
history1 = TCN_model1.fit(X,y,validation_split=0.33,epochs=60, batch_size=32,callbacks=callbacks_list, verbose=2)
endtime=time.time()
dtime=endtime-starttime
print("程序运行时间为：%.8s s" % dtime)  #时间显示到微秒
# Out:
# Train on 4882 samples, validate on 2406 samples
# Epoch 1/60
#
# Epoch 00001: val_loss improved from inf to 0.07087, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 4s - loss: 0.1668 - val_loss: 0.0709
# Epoch 2/60
#
# Epoch 00002: val_loss improved from 0.07087 to 0.05505, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0653 - val_loss: 0.0551
# Epoch 3/60
#
# Epoch 00003: val_loss improved from 0.05505 to 0.05289, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0590 - val_loss: 0.0529
# Epoch 4/60
#
# Epoch 00004: val_loss improved from 0.05289 to 0.04886, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0536 - val_loss: 0.0489
# Epoch 5/60
#
# Epoch 00005: val_loss improved from 0.04886 to 0.04616, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0520 - val_loss: 0.0462
# Epoch 6/60
#
# Epoch 00006: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0495 - val_loss: 0.0555
# Epoch 7/60
#
# Epoch 00007: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0486 - val_loss: 0.0494
# Epoch 8/60
#
# Epoch 00008: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0458 - val_loss: 0.0486
# Epoch 9/60
#
# Epoch 00009: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0455 - val_loss: 0.0551
# Epoch 10/60
#
# Epoch 00010: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0432 - val_loss: 0.0481
# Epoch 11/60
#
# Epoch 00011: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0428 - val_loss: 0.0475
# Epoch 12/60
#
# Epoch 00012: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0419 - val_loss: 0.0475
# Epoch 13/60
#
# Epoch 00013: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0412 - val_loss: 0.0478
# Epoch 14/60
#
# Epoch 00014: val_loss did not improve from 0.04616
# 4882/4882 - 2s - loss: 0.0393 - val_loss: 0.0463
# Epoch 15/60
#
# Epoch 00015: val_loss improved from 0.04616 to 0.04550, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0385 - val_loss: 0.0455
# Epoch 16/60
#
# Epoch 00016: val_loss improved from 0.04550 to 0.04340, saving model to D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\12hourweights\TCN_model_weights_best.hdf5
# 4882/4882 - 2s - loss: 0.0366 - val_loss: 0.0434
# Epoch 17/60
#
# Epoch 00017: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0352 - val_loss: 0.0443
# Epoch 18/60
#
# Epoch 00018: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0348 - val_loss: 0.0490
# Epoch 19/60
#
# Epoch 00019: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0339 - val_loss: 0.0458
# Epoch 20/60
#
# Epoch 00020: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0331 - val_loss: 0.0447
# Epoch 21/60
#
# Epoch 00021: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0321 - val_loss: 0.0476
# Epoch 22/60
#
# Epoch 00022: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0308 - val_loss: 0.0448
# Epoch 23/60
#
# Epoch 00023: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0293 - val_loss: 0.0480
# Epoch 24/60
#
# Epoch 00024: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0277 - val_loss: 0.0463
# Epoch 25/60
#
# Epoch 00025: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0287 - val_loss: 0.0495
# Epoch 26/60
#
# Epoch 00026: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0278 - val_loss: 0.0530
# Epoch 27/60
#
# Epoch 00027: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0268 - val_loss: 0.0449
# Epoch 28/60
#
# Epoch 00028: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0269 - val_loss: 0.0458
# Epoch 29/60
#
# Epoch 00029: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0256 - val_loss: 0.0464
# Epoch 30/60
#
# Epoch 00030: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0250 - val_loss: 0.0505
# Epoch 31/60
#
# Epoch 00031: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0244 - val_loss: 0.0496
# Epoch 32/60
#
# Epoch 00032: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0243 - val_loss: 0.0467
# Epoch 33/60
#
# Epoch 00033: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0234 - val_loss: 0.0477
# Epoch 34/60
#
# Epoch 00034: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0236 - val_loss: 0.0468
# Epoch 35/60
#
# Epoch 00035: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0221 - val_loss: 0.0478
# Epoch 36/60
#
# Epoch 00036: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0216 - val_loss: 0.0470
# Epoch 37/60
#
# Epoch 00037: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0212 - val_loss: 0.0469
# Epoch 38/60
#
# Epoch 00038: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0212 - val_loss: 0.0450
# Epoch 39/60
#
# Epoch 00039: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0205 - val_loss: 0.0475
# Epoch 40/60
#
# Epoch 00040: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0206 - val_loss: 0.0474
# Epoch 41/60
#
# Epoch 00041: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0198 - val_loss: 0.0477
# Epoch 42/60
#
# Epoch 00042: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0198 - val_loss: 0.0501
# Epoch 43/60
#
# Epoch 00043: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0192 - val_loss: 0.0475
# Epoch 44/60
#
# Epoch 00044: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0188 - val_loss: 0.0484
# Epoch 45/60
#
# Epoch 00045: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0179 - val_loss: 0.0461
# Epoch 46/60
#
# Epoch 00046: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0174 - val_loss: 0.0470
# Epoch 47/60
#
# Epoch 00047: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0172 - val_loss: 0.0466
# Epoch 48/60
#
# Epoch 00048: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0173 - val_loss: 0.0467
# Epoch 49/60
#
# Epoch 00049: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0176 - val_loss: 0.0471
# Epoch 50/60
#
# Epoch 00050: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0173 - val_loss: 0.0469
# Epoch 51/60
#
# Epoch 00051: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0172 - val_loss: 0.0476
# Epoch 52/60
#
# Epoch 00052: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0172 - val_loss: 0.0472
# Epoch 53/60
#
# Epoch 00053: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0171 - val_loss: 0.0474
# Epoch 54/60
#
# Epoch 00054: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0157 - val_loss: 0.0454
# Epoch 55/60
#
# Epoch 00055: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0160 - val_loss: 0.0470
# Epoch 56/60
#
# Epoch 00056: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0153 - val_loss: 0.0462
# Epoch 57/60
#
# Epoch 00057: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0153 - val_loss: 0.0459
# Epoch 58/60
#
# Epoch 00058: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0154 - val_loss: 0.0458
# Epoch 59/60
#
# Epoch 00059: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0148 - val_loss: 0.0451
# Epoch 60/60
#
# Epoch 00060: val_loss did not improve from 0.04340
# 4882/4882 - 2s - loss: 0.0154 - val_loss: 0.0454
# 程序运行时间为：114.3981 s

# %%
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = np.arange(60) + 1
plt.figure(figsize=(20,18))
plt.plot(epochs, loss, label='loss')
plt.plot(epochs, val_loss, label='val_loss')
plt.title("Effect of model capacity on validation loss\n")
plt.xlabel('Epoch #')
plt.ylabel('Validation Loss')
plt.legend()
plt.show()

# %%
filepath = "D:\桌面\空气质量预测综合\北京多站点空气质量数据集\北京天坛\\12hourweights\TCN_model_weights_best.hdf5"
TCN_model1.load_weights(filepath)

# %%
predict=TCN_model1.predict(test_x)
predict=scaler1.inverse_transform(predict)

# %%
tf.sqrt(tf.losses.mean_squared_error(predict,scaler1.inverse_transform(test_y))).numpy().mean()
# Out:
# 61.859267962157716

# %%
tf.losses.mae(predict,scaler1.inverse_transform(test_y)).numpy().mean()
# Out:
# 52.814752915198284

# %%
for i in range(7):
    loss1 = tf.sqrt(tf.losses.mean_squared_error(predict[:,i],scaler1.inverse_transform(test_y)[:,i])).numpy()
    print(i,":",loss1)
# Out:
# 0 : 27.028359053702435
# 1 : 43.96214109768066
# 2 : 57.30565530026039
# 3 : 63.20630809618839
# 4 : 72.3819224357687
# 5 : 74.46196173807284
# 6 : 85.88593224297873

# %%
for i in range(7):
    loss1 = tf.sqrt(tf.losses.mae(predict[:,i],scaler1.inverse_transform(test_y)[:,i])).numpy()
    print(i,":",loss1)
# Out:
# 0 : 4.333739289488505
# 1 : 5.450149329807454
# 2 : 6.1688026082295035
# 3 : 6.546275194811818
# 4 : 7.0484572122697084
# 5 : 7.1532491669739136
# 6 : 7.647943969466782

# %%
for i in range(7):
    plt.figure(figsize=(20,18))
    plt.plot(scaler1.inverse_transform(test_y)[:,i],label='TCN()')
    plt.plot(predict[:,i])
    plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler1.inverse_transform(test_y)[:,0],label='Tcn_prediction(hour1)')
plt.plot(predict[:,0],label='Groundtruth(hour1)')
plt.xlabel('test dataset(11/01/2016-12/31/2016)')
plt.ylabel('PM2.5 value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler1.inverse_transform(test_y)[:,3],label='Tcn_prediction(hour4)')
plt.plot(predict[:,3],label='Groundtruth(hour4)')
plt.xlabel('test dataset(11/01/2016-12/31/2016)')
plt.ylabel('PM2.5 value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(scaler1.inverse_transform(test_y)[:,6],label='Tcn_prediction(hour7)')
plt.plot(predict[:,6],label='Groundtruth(hour7)')
plt.xlabel('test dataset(11/01/2016-12/31/2016)')
plt.ylabel('PM2.5 value')
plt.legend()
plt.show()
